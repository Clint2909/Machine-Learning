# %%
import pandas as pd

# %%
dataset=pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=dataset[[ 'Age', 'EstimatedSalary','Gender_Male']]
dependent=dataset[['Purchased']]

# %%
from sklearn.model_selection  import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB

param_grid={'alpha':[1.0,5,10],'force_alpha':[True,False],'fit_prior':[True,False]}
grid=GridSearchCV(MultinomialNB(),param_grid,refit=True,verbose=3,n_jobs=-1,scoring='f1_weighted')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=MultinomialNB(), n_jobs=-1,
#              param_grid={'alpha': [1.0, 5, 10], 'fit_prior': [True, False],
#                          'force_alpha': [True, False]},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(X_test) 

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)

from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'alpha': 10, 'fit_prior': True, 'force_alpha': True}: 0.6323529411764707

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[64 15]
#  [27 14]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75        79
#            1       0.48      0.34      0.40        41
#
#     accuracy                           0.65       120
#    macro avg       0.59      0.58      0.58       120
# weighted avg       0.63      0.65      0.63       120

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.515282494597098

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.014155      0.001606         0.022207        0.010092         1.0
# 1        0.009871      0.001436         0.015404        0.001901         1.0
# 2        0.008524      0.001995         0.014402        0.003122         1.0
# 3        0.009369      0.001663         0.015370        0.002094         1.0
# 4        0.008964      0.002032         0.016054        0.001552           5
# 5        0.009039      0.001702         0.016174        0.003998           5
# 6        0.009373      0.001521         0.015164        0.000738           5
# 7        0.007895      0.001390         0.012895        0.002584           5
# 8        0.007956      0.001128         0.012890        0.002462          10
# 9        0.009298      0.001683         0.013062        0.002368          10
# 10       0.009341      0.002243         0.014700        0.001688          10
# 11       0.007949      0.000898         0.013671        0.001525          10
#
#    param_fit_prior param_force_alpha  \
# 0             True              True
# 1             True             False
# 2            False              True
# 3            False             False
# 4             True              True
# 5             True             False
# 6            False              True
# 7            False             False
# 8             True              True
# 9             True             False
# 10           False              True
# 11           False             False
#
#                                                params  split0_test_score  \
# 0   {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.618850
# 1   {'alpha': 1.0, 'fit_prior': True, 'force_alpha...           0.618850
# 2   {'alpha': 1.0, 'fit_prior': False, 'force_alph...           0.527697
# 3   {'alpha': 1.0, 'fit_prior': False, 'force_alph...           0.527697
# 4   {'alpha': 5, 'fit_prior': True, 'force_alpha':...           0.618850
# 5   {'alpha': 5, 'fit_prior': True, 'force_alpha':...           0.618850
# 6   {'alpha': 5, 'fit_prior': False, 'force_alpha'...           0.507692
# 7   {'alpha': 5, 'fit_prior': False, 'force_alpha'...           0.507692
# 8   {'alpha': 10, 'fit_prior': True, 'force_alpha'...           0.644599
# 9   {'alpha': 10, 'fit_prior': True, 'force_alpha'...           0.644599
# 10  {'alpha': 10, 'fit_prior': False, 'force_alpha...           0.507692
# 11  {'alpha': 10, 'fit_prior': False, 'force_alpha...           0.507692
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.503106           0.616071           0.609571
# 1            0.503106           0.616071           0.609571
# 2            0.472527           0.540136           0.578065
# 3            0.472527           0.540136           0.578065
# 4            0.503106           0.616071           0.609571
# 5            0.503106           0.616071           0.609571
# 6            0.488602           0.540136           0.578065
# 7            0.488602           0.540136           0.578065
# 8            0.503106           0.616071           0.609571
# 9            0.503106           0.616071           0.609571
# 10           0.469075           0.540136           0.578065
# 11           0.469075           0.540136           0.578065
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.619155         0.593351        0.045254                3
# 1            0.619155         0.593351        0.045254                3
# 2            0.558458         0.535377        0.035740                7
# 3            0.558458         0.535377        0.035740                7
# 4            0.619155         0.593351        0.045254                3
# 5            0.619155         0.593351        0.045254                3
# 6            0.541831         0.531265        0.030843                9
# 7            0.541831         0.531265        0.030843                9
# 8            0.619155         0.598500        0.049159                1
# 9            0.619155         0.598500        0.049159                1
# 10           0.541831         0.527360        0.036681               11
# 11           0.541831         0.527360        0.036681               11
